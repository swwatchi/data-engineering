# %%
import requests  # [+] HTTP 요청
from bs4 import BeautifulSoup  # [+] 웹스크래핑
import pandas as pd

# %%
# 1. User-Agent 설정
# 우리가 실제 크롬 브라우저를 사용하는 일반 사용자인 것처럼 서버를 속이는 '위장 신분증' 역할
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
}

search_keyword = 'AI' # [+] 검색 키워드
url = f'https://search.naver.com/search.naver?where=news&query={search_keyword}'  # 검색한 웹페이지 주소

# %%
# 2. 페이지 요청 및 파싱
res = requests.get(url,headers = headers)  # [+] 네이버 서버에 페이지 정보 요청(GET)
res.raise_for_status() # 서버가 응답을 잘 주었는지 확인(정상 200, 페이지 없음 404 등)
soup = BeautifulSoup(res.text, 'html.parser')  # [+] BeautifulSoup 객체 생성

# %%
# 3. 질문자님이 찾은 클래스로 타겟팅 (띄어쓰기를 '.'으로 변경)
# [+] 찾고자 하는 HTML 태그 정의
target_class = 'span.sds-comps-text.sds-comps-text-ellipsis.sds-comps-text-ellipsis-1.sds-comps-text-type-headline1'
title_spans = soup.select(target_class) # [+] 조건에 맞는 모든 태그를 찾아 리스트로 저장

extracted_data = []

# %%
title_spans[0].
# Out:
# "150조 국민성장펀드, 새만금·소버린AI 등 '2차 프로젝트' 선정"

# %%
# 4. 데이터 추출
for span in title_spans:
    # [+] 기사 제목 추출
    title = span.text.strip()
    
    # [+] 기사 링크 추출: 제목(span)을 클릭 가능하게 만드는 부모 <a> 태그를 역추적하여 찾음
    parent_a_tag = span.find_parent('a')
    link = parent_a_tag['href'] if parent_a_tag and parent_a_tag.has_attr('href') else "링크 없음"
    
    extracted_data.append({
        '제목': title,
        '링크': link
    })

# %%
extracted_data
# Out:
# [{'제목': "150조 국민성장펀드, 새만금·소버린AI 등 '2차 프로젝트' 선정",
#   '링크': 'https://www.yna.co.kr/view/AKR20260414109100002?input=1195m'},
#  {'제목': "삼성SDS, 'AI 국회' 오픈…의원·보좌관, 생성형 AI 쓴다",
#   '링크': 'https://www.newsis.com/view/NISX20260413_0003589435'},
#  {'제목': '사라지는 남성 청년 일자리… “여성·기성세대·AI 동시 타격"',
#   '링크': 'https://www.chosun.com/economy/economy_general/2026/04/14/IF2KAPWNOFFQ5EM4K6B3DJXHLQ/?utm_source=naver&utm_medium=referral&utm_campaign=naver-news'},
#  {'제목': '정의선 현대차 회장 “미래 성장 핵심축은 로보틱스와 AI”',
#   '링크': 'https://www.kmib.co.kr/article/view.asp?arcid=1776066985&code=11151400&cp=nv'},
#  {'제목': '한국, 인구당 AI 특허 건수 세계 1위…AI 이용률 증가폭도 최고',
#   '링크': 'https://www.yna.co.kr/view/AKR20260414000700091?input=1195m'},
#  {'제목': '부산환경공단, AI 온실가스 관리 플랫폼 개발',
#   '링크': 'https://www.segye.com/newsView/20260414515604?OutUrl=naver'},
#  {'제목': '강남 누비는 ‘AI 택시’…기사들은 “퇴출 걱정”',
#   '링크': 'https://www.hani.co.kr/arti/economy/it/1254052.html'},
#  {'제목': '서술·논술형 답안분석도, 피드백도…전남교육청 "AI채점"',
#   '링크': 'https://www.newsis.com/view/NISX20260414_0003590010'},
#  {'제목': '[AI픽] AI 캐리커처 유행, 신원 사칭·피싱 위험 키운다',
#   '링크': 'https://www.yna.co.kr/view/AKR20260414031800017?input=1195m'},
#  {'제목': '의정 지원도 AI로…삼성SDS, 국회 AI 플랫폼 구축',
#   '링크': 'https://zdnet.co.kr/view/?no=20260414092127'}]

# %%
# 5. [+] DataFrame으로 변환 및 확인
df = pd.DataFrame(extracted_data)
print(f"총 {len(df)}개의 기사를 추출했습니다.\n")
display(df)
# Out:
# 총 10개의 기사를 추출했습니다.
#                                       제목  \
# 0  150조 국민성장펀드, 새만금·소버린AI 등 '2차 프로젝트' 선정
# 1    삼성SDS, 'AI 국회' 오픈…의원·보좌관, 생성형 AI 쓴다
# 2     사라지는 남성 청년 일자리… “여성·기성세대·AI 동시 타격"
# 3       정의선 현대차 회장 “미래 성장 핵심축은 로보틱스와 AI”
# 4  한국, 인구당 AI 특허 건수 세계 1위…AI 이용률 증가폭도 최고
# 5              부산환경공단, AI 온실가스 관리 플랫폼 개발
# 6            강남 누비는 ‘AI 택시’…기사들은 “퇴출 걱정”
# 7        서술·논술형 답안분석도, 피드백도…전남교육청 "AI채점"
# 8      [AI픽] AI 캐리커처 유행, 신원 사칭·피싱 위험 키운다
# 9         의정 지원도 AI로…삼성SDS, 국회 AI 플랫폼 구축
#
#                                                   링크
# 0  https://www.yna.co.kr/view/AKR2026041410910000...
# 1  https://www.newsis.com/view/NISX20260413_00035...
# 2  https://www.chosun.com/economy/economy_general...
# 3  https://www.kmib.co.kr/article/view.asp?arcid=...
# 4  https://www.yna.co.kr/view/AKR2026041400070009...
# 5  https://www.segye.com/newsView/20260414515604?...
# 6  https://www.hani.co.kr/arti/economy/it/1254052...
# 7  https://www.newsis.com/view/NISX20260414_00035...
# 8  https://www.yna.co.kr/view/AKR2026041403180001...
# 9        https://zdnet.co.kr/view/?no=20260414092127
